# %% [markdown]
# <a href="https://colab.research.google.com/github/sjasthi/python_23/blob/main/ch_2_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Operators
#
# https://www.w3schools.com/python/python_operators.asp

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Addition (+)

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15
# 25

# %%
a = 2
b = 1
c = a + b
c = c + c
print(c)
# Out:
# 6

# %% [markdown]
# ### Subtraction

# %%
a = 10
b = 5
print(a - b)

c = a - b 
d = a - c
print(d)
# Out:
# 5
# 5
