# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sjasthi/python101/blob/main/Labs/Lab1_Typing_and_Running_Python_Code.ipynb)
#
# # Lab 1: Typing and Running Python Code (10 points)
#
# **Learn and Help — Python 101**
# www.learnandhelp.com
#
# ## How to Open This Lab in Your Own Colab
#
# **Option A — Click the button (easiest)**
# 1. Click the **"Open in Colab"** button above ☝️
# 2. Your browser will open this lab inside Google Colab
# 3. Go to **File → Save a copy in Drive**
# 4. A new copy will open in a new tab — this is now *your own* copy, saved to *your* Google Drive
# 5. You can close the original tab and work only in your new copy
#
# **Option B — If your teacher shared the `.ipynb` file directly (email, Google Classroom, USB, etc.)**
# 1. Go to **https://colab.research.google.com/**
# 2. Click **File → Upload notebook**
# 3. Choose **Browse** and select the `Lab1_Typing_and_Running_Python_Code.ipynb` file you were given
# 4. Once it opens, go to **File → Save a copy in Drive** so your work is saved
#
# > ⚠️ **Important:** Always do "Save a copy in Drive" first! If you skip this step, your work might not be saved when you close the tab.
#
# ---

# %% [markdown]
# ## Instructions
#
# You don't need to understand *how* this code works yet — we'll learn all of that soon! Today's lab is just about practicing three things every programmer does every single day:
#
# 1. **Type** the code exactly as shown (spelling, quotes, and capital letters matter!)
# 2. **Run** the cell (click the cell, then press **Shift + Enter**, or click the ▶️ Run button)
# 3. **Look** at the output and see what it produces
#
# There are **5 snippets** below, each worth **2 points**, for a total of **10 points**.
#
# For each snippet:
# - Read the code shown in the instructions
# - Type it into the empty code cell right below it
# - Run the cell
# - Make sure your output matches what's expected
#
# When you're done with all 5, follow the **Submission Checklist** at the end of this lab.

# %% [markdown]
# ---
# ## Snippet 1: Say Hello (2 points)
#
# Type this code into the cell below and run it:
#
# ```python
# print("Hello, World!")
# print("My name is Python.")
# print("I am learning to code!")
# ```

# %% [markdown]
# ---
# ## Snippet 2: A Little Math (2 points)
#
# Type this code into the cell below and run it:
#
# ```python
# print(5 + 3)
# print(10 - 4)
# print(6 * 7)
# ```

# %% [markdown]
# ---
# ## Snippet 3: My Info in Boxes (2 points)
#
# Type this code into the cell below and run it. Feel free to change `"Maya"`, `12`, and the email to your own info if you'd like!
#
# ```python
# name = "Maya"
# age = 12
# email = "maya@example.com"
# print(name)
# print(age)
# print(email)
# ```
#
# > **Hint:** `name`, `age`, and `email` are called *variables* — think of them as labeled boxes that hold a value. We'll learn all about these soon!

# %% [markdown]
# ---
# ## Snippet 4: Doing Some Math with Variables (2 points)
#
# Type this code into the cell below and run it:
#
# ```python
# apples = 5
# oranges = 3
# total = apples + oranges
# print(total)
# ```

# %% [markdown]
# ---
# ## Snippet 5: Calculating an Average (2 points)
#
# Type this code into the cell below and run it:
#
# ```python
# math_marks = 90
# science_marks = 85
# total_marks = math_marks + science_marks
# average_marks = total_marks / 2
# print(total_marks)
# print(average_marks)
# ```
#
# > **Hint:** The `/` symbol divides two numbers. We'll cover this and other math symbols in a future class.

# %% [markdown]
# ---
# ## Submission Checklist ✅
#
# Before you submit, make sure:
#
# - [ ] All 5 code cells have been typed in (not copy-pasted!) and run
# - [ ] Each cell shows an output below it with no error messages
# - [ ] You saved your notebook (**File → Save**)
# - [ ] You took a screenshot showing all 5 snippets and their output
# - [ ] You submitted your screenshot (or shared notebook link) on **Google Classroom**
#
# Great job today — you just typed and ran real Python code! 🎉
