# %% [markdown]
# # Python 101 - Lab 14: File Reading
# ## Reading Numbers from a File
#
# **Name:** ___________________________
#
# **Date:** ___________________________
#
# **Total Points:** 10 points
#
# ---
#
# ### 📚 Learning Objectives
# In this lab, you will:
# - Read data from a text file using Python
# - Process numerical data from a file
# - Calculate count, sum, and average of numbers
# - Use the `with` statement for proper file handling
#
# ### 📝 Instructions
# You have a file called **`numbers.txt`** that contains several numbers, each on a separate line. Your job is to:
# 1. Read all the numbers from the file
# 2. Count how many numbers there are
# 3. Calculate the sum of all numbers
# 4. Calculate the average of all numbers
#
# ### 📤 Submission
# When you're done, submit this completed `.ipynb` file to Google Classroom.
#
# ---

# %% [markdown]
# ## Step 0: Create the Sample Data File
#
# First, let's create the `numbers.txt` file with some sample numbers.
#
# **Run this cell to create your data file:**

# %%
# This creates a file called numbers.txt with sample numbers
# Each number is on a separate line

with open('numbers.txt', 'w') as file:
    file.write('10\n')
    file.write('25\n')
    file.write('30\n')
    file.write('15\n')
    file.write('20\n')
    file.write('35\n')
    file.write('40\n')
    file.write('5\n')

print("✅ File 'numbers.txt' has been created successfully!")
print("The file contains 8 numbers.")

# %% [markdown]
# ## Step 1: Create the Sample Data File (2 points)
#
# First, let's create the `numbers.txt` file with some sample numbers.
#
# **Run this cell to create your data file:**

# %%
# TODO: Create numbers.txt with your own numbers
# (see the previous coding cell for example)

# This creates a file called numbers.txt with sample numbers
# Each number is on a separate line

with open('numbers.txt', 'w') as file:
   # Your code goes here

print("✅ File 'numbers.txt' has been created successfully!")
print("The file contains 8 numbers.")

# %% [markdown]
# ## Step 2: Read and Display the File Contents (2 points)
#
# Let's first read and display what's in the file to see what we're working with.
#
# **💡 Hint:** Use the `with` statement and a `for` loop to read each line.
#
# **Your task:** Complete the code below to read and print each line from the file.

# %%
# TODO: Read and display the contents of numbers.txt

file_name = 'numbers.txt'

print("Contents of the file:")
print("-" * 20)

# Write your code here to open the file and print each line
# Use: with open(file_name) as file_object:

# %% [markdown]
# ## Step 3: Calculate Count, Sum, and Average (6 points)
#
# Now for the main task! You need to:
# 1. Read all numbers from the file
# 2. Count how many numbers there are
# 3. Calculate the sum of all numbers
# 4. Calculate the average
#
# ### 💡 Helpful Hints:
# - When you read a line from a file, it's a **string**. Use `int()` or `float()` to convert it to a number.
# - Each line has a newline character (`\n`) at the end. The `strip()` method can help remove it.
# - Use variables like `count`, `total`, to keep track of your calculations.
# - Remember: **Average = Sum ÷ Count**
#
# ### 🎯 Expected Output:
# ```
# Count of numbers: 8
# Sum of numbers: 180
# Average of numbers: 22.5
# ```
#
# **Your task:** Complete the code below.

# %%
# TODO: Calculate count, sum, and average of numbers in the file

file_name = 'numbers.txt'

# Initialize variables
count = 0
total = 0

# Read the file and process each number
with open(file_name) as file_object:
    for each_line in file_object:
        # Remove whitespace and newline characters
        # TODO: Use strip() on each_line


        # Convert the string to a number
        # TODO: Use int() or float() to convert


        # Add to your count
        # TODO: Increment count by 1


        # Add to your total
        # TODO: Add the number to total


# Calculate the average
# TODO: Calculate average = total / count


# Display the results
print("📊 Results:")
print("=" * 30)
print(f"Count of numbers: {count}")
print(f"Sum of numbers: {total}")
print(f"Average of numbers: {average}")

# %% [markdown]
# ## 🌟 Bonus Challenge (Optional - No extra points, just for fun!)
#
# Can you also find:
# - The **largest** number in the file?
# - The **smallest** number in the file?
#
# **Hint:** You can use Python's built-in `max()` and `min()` functions, or keep track as you read!

# %%
# Bonus Challenge (Optional)
# Write your code here to find the largest and smallest numbers

# %% [markdown]
# ## ✅ Grading Rubric
#
# | Task | Points |
# |------|--------|
# | Step 1: Create the data file | 2 |
# | Step 2: Read and display file contents | 2 |
# | Step 3: Calculate count correctly | 2 |
# | Step 3: Calculate sum correctly | 2 |
# | Step 3: Calculate average correctly | 2 |
# | **Total** | **10** |
#
# ---
#
# ## 🎓 What You Learned
# - How to read data from a text file
# - How to convert strings to numbers
# - How to process data line by line
# - How to calculate statistics (count, sum, average)
# - Why the `with` statement is important for file handling
#
# **Great job! 🎉 Don't forget to submit your completed notebook to Google Classroom!**
