# %% [markdown]
# # Assignment: Python Functions
# **Total Points: 25**
#
# ---
#
# ## Instructions
#
# In this assignment, you will demonstrate your understanding of Python functions by implementing five different functions. Each function will use **arithmetic operations, conditions, and loops** that you have learned.
#
# ### How to Complete This Assignment:
#
# 1. Read each problem carefully
# 2. Implement your solution in the designated code cell
# 3. Do NOT modify the function names or parameters
# 4. After completing all problems, run the **Auto-Grader** cell at the end
# 5. The auto-grader will show your score and feedback for each problem
#
# ### Grading Breakdown:
# - **Problem 1:** 3 points (Basic arithmetic)
# - **Problem 2:** 4 points (Loops with range)
# - **Problem 3:** 5 points (Conditions)
# - **Problem 4:** 6 points (Loops with conditions)
# - **Problem 5:** 7 points (Complex logic with nested loops)
#
# **Total: 25 points**
#
# ---

# %% [markdown]
# ## Problem 1: Circle Area Calculator (3 points)
#
# Write a function called `calculate_circle_area` that calculates the area of a circle given its radius.
#
# **Formula:** Area = π × r²
#
# **Requirements:**
# - Function name: `calculate_circle_area`
# - Parameter: `radius` (a positive number)
# - Returns: The area of the circle (float)
# - Use `3.14159` for π (pi)
#
# **Example:**
# ```python
# calculate_circle_area(5)    # Returns: 78.53975
# calculate_circle_area(10)   # Returns: 314.159
# calculate_circle_area(1)    # Returns: 3.14159
# ```

# %%
# YOUR CODE HERE
def calculate_circle_area(radius):
    """
    Calculate the area of a circle given its radius.

    Args:
        radius (float): The radius of the circle

    Returns:
        float: The area of the circle
    """
    pass  # Remove this and write your code


# ====================================
# call the function and test it
#
#
#

# %% [markdown]
# ## Problem 2: Sum of Range (4 points)
#
# Write a function called `sum_of_range` that calculates the sum of all integers from a starting number to an ending number (inclusive).
#
# **Requirements:**
# - Function name: `sum_of_range`
# - Parameters:
#   - `start` (an integer)
#   - `end` (an integer)
# - Returns: The sum of all numbers from start to end (int)
# - Use a loop to calculate the sum
#
# **Example:**
# ```python
# sum_of_range(1, 5)    # Returns: 15 (1+2+3+4+5)
# sum_of_range(10, 15)  # Returns: 75 (10+11+12+13+14+15)
# sum_of_range(5, 5)    # Returns: 5
# ```

# %%
# YOUR CODE HERE
def sum_of_range(start, end):
    """
    Calculate the sum of all integers from start to end (inclusive).

    Args:
        start (int): Starting number
        end (int): Ending number

    Returns:
        int: Sum of all numbers in the range
    """
    pass  # Remove this and write your code


# ====================================
# call the function and test it
#
#
#

# %% [markdown]
# ## Problem 3: Grade Classifier (5 points)
#
# Write a function called `get_letter_grade` that takes a numerical score and returns the corresponding letter grade.
#
# **Requirements:**
# - Function name: `get_letter_grade`
# - Parameter: `score` (a number between 0 and 100)
# - Returns: A letter grade (A, B, C, D, or F) as a string
# - Use conditional statements (if/elif/else)
#
# **Grading Scale:**
# - A: 90-100
# - B: 80-89
# - C: 70-79
# - D: 60-69
# - F: Below 60
#
# **Example:**
# ```python
# get_letter_grade(95)   # Returns: 'A'
# get_letter_grade(82)   # Returns: 'B'
# get_letter_grade(55)   # Returns: 'F'
# ```

# %%
# YOUR CODE HERE
def get_letter_grade(score):
    """
    Convert a numerical score to a letter grade.

    Args:
        score (float): Numerical score (0-100)

    Returns:
        str: Letter grade (A, B, C, D, or F)
    """
    pass  # Remove this and write your code


# ====================================
# call the function and test it
#
#
#

# %% [markdown]
# ## Problem 4: Count Even Numbers (6 points)
#
# Write a function called `count_evens` that counts how many even numbers exist in a range from a starting number to an ending number (inclusive).
#
# **Requirements:**
# - Function name: `count_evens`
# - Parameters:
#   - `start` (an integer)
#   - `end` (an integer)
# - Returns: The count of even numbers in the range (int)
# - Use a loop and conditional statements
# - Remember: A number is even if `number % 2 == 0`
#
# **Example:**
# ```python
# count_evens(1, 10)   # Returns: 5 (2, 4, 6, 8, 10)
# count_evens(5, 15)   # Returns: 6 (6, 8, 10, 12, 14)
# count_evens(2, 2)    # Returns: 1
# ```

# %%
# YOUR CODE HERE
def count_evens(start, end):
    """
    Count how many even numbers exist in a range.

    Args:
        start (int): Starting number
        end (int): Ending number

    Returns:
        int: Count of even numbers in the range
    """
    pass  # Remove this and write your code


# ====================================
# call the function and test it
#
#
#

# %% [markdown]
# ## Problem 5: Multiplication Table Sum (7 points)
#
# Write a function called `multiplication_table_sum` that calculates the sum of all values in a multiplication table up to a given number.
#
# For example, if `n = 3`, the multiplication table is:
# ```
# 1×1=1  1×2=2  1×3=3
# 2×1=2  2×2=4  2×3=6
# 3×1=3  3×2=6  3×3=9
# ```
# Sum = 1+2+3+2+4+6+3+6+9 = 36
#
# **Requirements:**
# - Function name: `multiplication_table_sum`
# - Parameter: `n` (a positive integer)
# - Returns: The sum of all products in the n×n multiplication table (int)
# - Use nested loops (a loop inside another loop)
#
# **Example:**
# ```python
# multiplication_table_sum(3)   # Returns: 36
# multiplication_table_sum(4)   # Returns: 100
# multiplication_table_sum(5)   # Returns: 225
# ```

# %%
#YOUR CODE HERE
def multiplication_table_sum(n):
    """
    Calculate the sum of all values in an n×n multiplication table.

    Args:
        n (int): Size of the multiplication table

    Returns:
        int: Sum of all products in the table
    """
    pass  # Remove this and write your code


# ====================================
# call the function and test it
#
#
#

# %% [markdown]
# ---
#
# # Auto-Grader
#
# Run the cell below to test your functions and see your score.
#
# **Important:** Make sure you have implemented all functions above before running the auto-grader.

# %%
# AUTO-GRADER - DO NOT MODIFY THIS CELL
# Once you implemented all the above code,
# run this auto-grader to see your score.

def run_tests():
    """
    Automated grading system for the functions assignment.
    """
    total_score = 0
    max_score = 25

    print("="*60)
    print("RUNNING AUTO-GRADER")
    print("="*60)
    print()

    # Test Problem 1: calculate_circle_area (3 points)
    print("Testing Problem 1: calculate_circle_area (3 points)")
    print("-" * 60)
    problem1_score = 0
    try:
        test_cases = [
            (5, 78.53975),
            (10, 314.159),
            (1, 3.14159),
            (7, 153.93804),
        ]

        all_passed = True
        for radius, expected in test_cases:
            result = calculate_circle_area(radius)
            if abs(result - expected) < 0.001:
                print(f"✓ calculate_circle_area({radius}) = {result} [PASS]")
            else:
                print(f"✗ calculate_circle_area({radius}) = {result}, expected {expected} [FAIL]")
                all_passed = False

        if all_passed:
            problem1_score = 3
            print(f"\n✓ Problem 1: {problem1_score}/3 points\n")
        else:
            print(f"\n✗ Problem 1: {problem1_score}/3 points (Some tests failed)\n")
    except Exception as e:
        print(f"✗ Error running tests: {e}")
        print(f"\n✗ Problem 1: {problem1_score}/3 points\n")

    total_score += problem1_score

    # Test Problem 2: sum_of_range (4 points)
    print("Testing Problem 2: sum_of_range (4 points)")
    print("-" * 60)
    problem2_score = 0
    try:
        test_cases = [
            (1, 5, 15),
            (10, 15, 75),
            (5, 5, 5),
            (1, 10, 55),
            (20, 25, 135),
        ]

        all_passed = True
        for start, end, expected in test_cases:
            result = sum_of_range(start, end)
            if result == expected:
                print(f"✓ sum_of_range({start}, {end}) = {result} [PASS]")
            else:
                print(f"✗ sum_of_range({start}, {end}) = {result}, expected {expected} [FAIL]")
                all_passed = False

        if all_passed:
            problem2_score = 4
            print(f"\n✓ Problem 2: {problem2_score}/4 points\n")
        else:
            print(f"\n✗ Problem 2: {problem2_score}/4 points (Some tests failed)\n")
    except Exception as e:
        print(f"✗ Error running tests: {e}")
        print(f"\n✗ Problem 2: {problem2_score}/4 points\n")

    total_score += problem2_score

    # Test Problem 3: get_letter_grade (5 points)
    print("Testing Problem 3: get_letter_grade (5 points)")
    print("-" * 60)
    problem3_score = 0
    try:
        test_cases = [
            (95, 'A'),
            (82, 'B'),
            (55, 'F'),
            (90, 'A'),
            (89, 'B'),
            (70, 'C'),
            (60, 'D'),
        ]

        all_passed = True
        for score, expected in test_cases:
            result = get_letter_grade(score)
            if result == expected:
                print(f"✓ get_letter_grade({score}) = '{result}' [PASS]")
            else:
                print(f"✗ get_letter_grade({score}) = '{result}', expected '{expected}' [FAIL]")
                all_passed = False

        if all_passed:
            problem3_score = 5
            print(f"\n✓ Problem 3: {problem3_score}/5 points\n")
        else:
            print(f"\n✗ Problem 3: {problem3_score}/5 points (Some tests failed)\n")
    except Exception as e:
        print(f"✗ Error running tests: {e}")
        print(f"\n✗ Problem 3: {problem3_score}/5 points\n")

    total_score += problem3_score

    # Test Problem 4: count_evens (6 points)
    print("Testing Problem 4: count_evens (6 points)")
    print("-" * 60)
    problem4_score = 0
    try:
        test_cases = [
            (1, 10, 5),
            (5, 15, 6),
            (2, 2, 1),
            (1, 20, 10),
            (10, 20, 6),
            (3, 7, 2),
        ]

        all_passed = True
        for start, end, expected in test_cases:
            result = count_evens(start, end)
            if result == expected:
                print(f"✓ count_evens({start}, {end}) = {result} [PASS]")
            else:
                print(f"✗ count_evens({start}, {end}) = {result}, expected {expected} [FAIL]")
                all_passed = False

        if all_passed:
            problem4_score = 6
            print(f"\n✓ Problem 4: {problem4_score}/6 points\n")
        else:
            print(f"\n✗ Problem 4: {problem4_score}/6 points (Some tests failed)\n")
    except Exception as e:
        print(f"✗ Error running tests: {e}")
        print(f"\n✗ Problem 4: {problem4_score}/6 points\n")

    total_score += problem4_score

    # Test Problem 5: multiplication_table_sum (7 points)
    print("Testing Problem 5: multiplication_table_sum (7 points)")
    print("-" * 60)
    problem5_score = 0
    try:
        test_cases = [
            (3, 36),
            (4, 100),
            (5, 225),
            (1, 1),
            (2, 9),
            (6, 441),
        ]

        all_passed = True
        for n, expected in test_cases:
            result = multiplication_table_sum(n)
            if result == expected:
                print(f"✓ multiplication_table_sum({n}) = {result} [PASS]")
            else:
                print(f"✗ multiplication_table_sum({n}) = {result}, expected {expected} [FAIL]")
                all_passed = False

        if all_passed:
            problem5_score = 7
            print(f"\n✓ Problem 5: {problem5_score}/7 points\n")
        else:
            print(f"\n✗ Problem 5: {problem5_score}/7 points (Some tests failed)\n")
    except Exception as e:
        print(f"✗ Error running tests: {e}")
        print(f"\n✗ Problem 5: {problem5_score}/7 points\n")

    total_score += problem5_score

    # Final Results
    print("="*60)
    print("FINAL RESULTS")
    print("="*60)
    print(f"Problem 1: {problem1_score}/3 points")
    print(f"Problem 2: {problem2_score}/4 points")
    print(f"Problem 3: {problem3_score}/5 points")
    print(f"Problem 4: {problem4_score}/6 points")
    print(f"Problem 5: {problem5_score}/7 points")
    print("-" * 60)
    print(f"TOTAL SCORE: {total_score}/{max_score} points ({(total_score/max_score)*100:.1f}%)")
    print("="*60)

    if total_score == max_score:
        print("\n🎉 Perfect score! Excellent work!")
    elif total_score >= 20:
        print("\n👍 Great job! Almost there!")
    elif total_score >= 15:
        print("\n💪 Good effort! Keep working on the problems.")
    else:
        print("\n📚 Keep practicing! Review the problem requirements.")

# Run the auto-grader
run_tests()

# %% [markdown]
# ---
#
# ## Submission Instructions
#
# 1. Make sure you have completed all 5 problems
# 2. Run the auto-grader cell to verify your score
# 3. Save your notebook
# 4. Submit your `.ipynb` file through Google Classroom
#
# **Due Date:** [Insert due date here]
#
# ---
#
# ## Tips for Success
#
# - Test your functions manually before running the auto-grader
# - Pay attention to the return type (int, float, string)
# - Read the problem requirements carefully
# - Use descriptive variable names
# - Add comments to explain your logic
# - Remember that function names and parameters must match exactly as specified
# - For loops, remember to use `range()` function
# - For conditions, use `if`, `elif`, and `else` statements
#
# Good luck! 🚀
