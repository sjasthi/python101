# %% [markdown]
# # 🎓 Python 101 - Lab 17: List Traversals
# ## Student Grade Manager
#
# **Name:** _________________________
# **Date:** _________________________
# **Points:** 10 points (2 points per coding problem)
#
# ---
#
# ## 📋 Lab Overview
#
# In this lab, you'll build a **Student Grade Manager** that demonstrates the power of:
# - **Map**: Transforming all scores (adding bonus points)
# - **Filter**: Selecting specific items (passing grades only)
# - **Reduce**: Combining to one value (calculating average)
# - **Enumerate**: Showing ranked lists with numbers
#
# ---
#
# ## 🎯 Scenario
#
# You're a teacher's assistant helping to process final exam scores! The teacher wants you to:
# 1. Add 5 bonus points to everyone's score (extra credit assignment!)
# 2. See which students are passing (score ≥ 60)
# 3. Calculate the class average
# 4. Create a ranked leaderboard
#
# Let's help process these grades!
#
# ---

# %% [markdown]
# ## 📊 Sample Data (Run This Cell First!)
#
# Here's our class data. Run this cell to set up the student names and their test scores.

# %%
# Student names
students = ["Alex", "Bailey", "Casey", "Drew", "Elliot", "Frankie", "Gray", "Harper"]

# Original test scores (out of 100)
original_scores = [78, 85, 55, 92, 68, 45, 88, 72]

# Let's see the original data
print("📚 Original Class Scores:")
print("=" * 40)
for i in range(len(students)):
    print(f"{students[i]}: {original_scores[i]}")
print("=" * 40)
print(f"Total students: {len(students)}")

# %% [markdown]
# ---
#
# ## ✨ Problem 1: Add Bonus Points (MAP) - 2 points
#
# The teacher is giving everyone **5 bonus points** for completing an extra credit assignment!
#
# **Your Task:**
# - Create a new list called `bonus_scores`
# - Add 5 points to each original score
# - Print the new scores
#
# **Hints:**
# - Use a `for` loop to go through each score
# - Add 5 to each score: `score + 5`
# - Use `.append()` to add to the new list
# - Remember: This creates a NEW list; the original stays the same!
#
# **Expected Output Format:**
# ```
# 📈 Scores After 5-Point Bonus:
# Alex: 78 → 83
# Bailey: 85 → 90
# ...
# ```

# %%
# Problem 1: Add 5 bonus points to all scores

# Create an empty list for the new scores
bonus_scores = []

# TODO: Write your code here
# Loop through original_scores and add 5 to each score




# Print the results
print("📈 Scores After 5-Point Bonus:")
print("=" * 40)
# TODO: Print each student's original score and new score
# Use a loop with range(len(students)) to access both lists

# %% [markdown]
# ---
#
# ## 🎯 Problem 2: Filter Passing Grades (FILTER) - 2 points
#
# Now let's see which students are passing! A passing grade is **60 or higher**.
#
# **Your Task:**
# - Create a new list called `passing_students` for student names who passed
# - Create a new list called `passing_scores` for their scores
# - Only include students with bonus_scores ≥ 60
# - Print the passing students and how many passed
#
# **Hints:**
# - Use a `for` loop with `range(len(students))`
# - Use an `if` statement to check: `if bonus_scores[i] >= 60:`
# - Append BOTH the name and score to their respective lists
#
# **Expected Output Format:**
# ```
# ✅ Passing Students (Score ≥ 60):
# Alex: 83
# Bailey: 90
# ...
# Total passing: 6 out of 8 students
# ```

# %%
# Problem 2: Filter to show only passing grades (≥ 60)

# Create empty lists for passing students
passing_students = []
passing_scores = []

# TODO: Write your code here
# Loop through and check if bonus_scores[i] >= 60
# If yes, append students[i] to passing_students
# and append bonus_scores[i] to passing_scores





# Print the results
print("✅ Passing Students (Score ≥ 60):")
print("=" * 40)
# TODO: Print each passing student and their score



print("=" * 40)
# TODO: Print total passing students
# Format: "Total passing: X out of Y students"

# %% [markdown]
# ---
#
# ## 📊 Problem 3: Calculate Class Average (REDUCE) - 2 points
#
# Let's find out the class average for the bonus scores!
#
# **Your Task:**
# - Calculate the sum of all bonus_scores
# - Divide by the number of students to get the average
# - Print the average rounded to 2 decimal places
#
# **Hints:**
# - Start with `total = 0`
# - Loop through bonus_scores and add each score to total
# - Calculate average: `total / len(bonus_scores)`
# - Use `round(average, 2)` to round to 2 decimal places
# - **OR** use Python's built-in `sum()` function!
#
# **Expected Output Format:**
# ```
# 📊 Class Statistics:
# Total points earned: 590
# Number of students: 8
# Class average: 73.75
# ```

# %%
# Problem 3: Calculate the class average

# Method 1: Using a loop
total = 0
# TODO: Write your code here
# Loop through bonus_scores and add each score to total



# Calculate average
# TODO: Divide total by number of students
average = 0  # Replace with your calculation

# Print the results
print("📊 Class Statistics:")
print("=" * 40)
print(f"Total points earned: {total}")
print(f"Number of students: {len(bonus_scores)}")
print(f"Class average: {round(average, 2)}")
print("=" * 40)

# BONUS TIP: You could also use sum(bonus_scores) / len(bonus_scores)

# %% [markdown]
# ---
#
# ## 🏆 Problem 4: Create Ranked Leaderboard (ENUMERATE) - 2 points
#
# Let's create a cool leaderboard showing student rankings!
#
# **Your Task:**
# - Use `enumerate()` to create a numbered list
# - Show each student's rank, name, and bonus score
# - Make it look like a real leaderboard!
#
# **Hints:**
# - Use `for rank, student in enumerate(students):`
# - Ranks start at 0, so add 1: `rank + 1`
# - Access the score using: `bonus_scores[rank]`
# - Add medals for top 3: 🥇 🥈 🥉
#
# **Expected Output Format:**
# ```
# 🏆 CLASS LEADERBOARD 🏆
# Rank #1: Alex - 83 points
# Rank #2: Bailey - 90 points
# ...
# ```
#
# **CHALLENGE:** Can you add medals (🥇 🥈 🥉) for the top 3 ranks?

# %%
# Problem 4: Create a ranked leaderboard using enumerate

print("🏆 CLASS LEADERBOARD 🏆")
print("=" * 40)

# TODO: Write your code here
# Use enumerate to loop through students
# Print rank number, student name, and their bonus score




print("=" * 40)

# BONUS CHALLENGE (Optional - No Extra Points):
# Add medals for top 3!
# Hint: Use an if-elif statement to check rank numbers

# %% [markdown]
# ---
#
# ## 🌟 Problem 5: Bonus - Find Top and Bottom Performers - 2 points
#
# Let's identify the highest and lowest scoring students!
#
# **Your Task:**
# - Find the highest score in bonus_scores
# - Find the student who got that score
# - Find the lowest score in bonus_scores
# - Find the student who got that score
# - Print both results
#
# **Hints:**
# - Use `max(bonus_scores)` to find highest score
# - Use `min(bonus_scores)` to find lowest score
# - Use `.index()` to find the position: `bonus_scores.index(max_score)`
# - Use that position to get the student name
# - **OR** loop through and track the max/min yourself!
#
# **Expected Output Format:**
# ```
# 🌟 Top Performer:
# Drew scored 97 points!
#
# 💪 Most Improved (Lowest Score):
# Frankie scored 50 points - Keep practicing!
# ```

# %%
# Problem 5: Find the top and bottom performers

# TODO: Find the maximum score
max_score = 0  # Replace with your code

# TODO: Find which student got the max score
# Hint: Use bonus_scores.index(max_score) to get position
# Then use students[position] to get name
top_student = ""  # Replace with your code

# TODO: Find the minimum score
min_score = 0  # Replace with your code

# TODO: Find which student got the min score
bottom_student = ""  # Replace with your code

# Print results
print("🌟 Top Performer:")
print(f"{top_student} scored {max_score} points!")
print()
print("💪 Most Improved (Lowest Score):")
print(f"{bottom_student} scored {min_score} points - Keep practicing!")

# %% [markdown]
# ---
#
# ## 🎉 Bonus Challenge (Optional - No Points, Just Fun!)
#
# Try these extra challenges if you finish early:
#
# 1. **Grade Letter Assignment**: Create a function that converts numeric scores to letter grades (A, B, C, D, F)
# 2. **Sort the Leaderboard**: Can you sort students by score from highest to lowest?
# 3. **Failing Students**: Create a list of students who are NOT passing (score < 60)
# 4. **Score Range**: Find the difference between highest and lowest scores
# 5. **Median Score**: Calculate the median (middle value) of the class scores
#
# Use the cell below for your bonus experiments!

# %%
# Bonus Challenge Area - Have fun experimenting!

# Your code here...

# %% [markdown]
# ---
#
# ## 📝 Reflection Questions
#
# Answer these questions in the markdown cell below (or on paper):
#
# 1. **Map vs Filter**: What's the main difference between map and filter operations?
# 2. **When to use enumerate**: Why is `enumerate()` helpful when creating ranked lists?
# 3. **Real-world application**: Where else could you use these list operations in real life?
#
# ---
#
# ## ✅ Submission Checklist
#
# Before submitting, make sure:
# - [ ] All 5 coding problems are completed
# - [ ] Your code runs without errors
# - [ ] Output is clearly displayed and formatted
# - [ ] You've tested your code with the sample data
# - [ ] Your name and date are at the top
#
# ---
#
# ## 🎯 Grading Rubric (10 points total)
#
# | Problem | Points | Criteria |
# |---------|--------|----------|
# | Problem 1 (Map) | 2 pts | Correctly adds 5 bonus points to all scores |
# | Problem 2 (Filter) | 2 pts | Correctly filters passing students (≥ 60) |
# | Problem 3 (Reduce) | 2 pts | Correctly calculates class average |
# | Problem 4 (Enumerate) | 2 pts | Correctly creates ranked leaderboard |
# | Problem 5 (Min/Max) | 2 pts | Correctly finds top and bottom performers |
#
# ---
#
# **Great work! You've mastered list traversals! 🚀**
#
# Remember:
# - **Map** = Transform all items
# - **Filter** = Select specific items
# - **Reduce** = Combine to one value
# - **Enumerate** = Get both index and value
