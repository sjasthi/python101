# %% [markdown]
# # Python 102
# ## Chapter 10: Classes and Object-Oriened Programming
# ### Siva.Jasthimetostate.edu

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#@title 1.Pet Class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#@title 2.Car Class

# %%
#@title 3.Personal Information Class

# %%
#@title 4.Employee Class

# %%
#@title 5.RetailItem Class

# %%
#@title 6.Patient Charges

# %%
#@title 7.Employee Management System

# %%
#@title 8.Cash Register

# %%
#@title 9.Trivia Game
