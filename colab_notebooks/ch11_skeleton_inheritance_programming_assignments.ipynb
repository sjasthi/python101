# %% [markdown]
# #Chapter 11. Inheritace
# ## Siva.Jasthi@metrostate.edu
# ### Python 101

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#@title 1. Employee

# %%
#@title 2.ProductionWorker Class

# %%
#@title 3.ShiftSupervisor Class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#@title PA 3: Person and Customer Classes

# %%
TODO:
PA 3 Plus: Person and Customer Classes;
           Querying the collection of Customer Classes.

Create a Person class with (name, address, telephone number)
Create a Customer class as a subclass of Person class.
The Customer class should have a data attribute for a customer number, and a Boolean data attribute indicating whether the customer wishes to be on a mailing list.
Demonstrate an instance of the Customer class in a simple program

Once these two classes are created, perform the following steps.

1. Create 10 Customers.
2. Add the customer objects to a list called "customer_list = [ customer1, customer2, customer3, customer4, .... customer10]
   -- this would be list of objects
3. Answer the following questions by looping through the customer_list

Q1. How many customers are there in customer_list?
Q2. How many custoemrs are there in the ZIP code 55126?
Q3. How many customers are there starting with the area code 651
Q4. Which customer has the longest name?
Q4. Which customer has the shortest name?
