# %% [markdown]
# # Learn and Help
# # Python 101 AUto Grader (Final Project)
# ## Siva Jasthi
# ## Class of 2026

# %%
#@title scratch pad
#INPUT_FILE_NAME = 'python_101_scores_small.csv'
INPUT_FILE_NAME = 'python_101_scores.csv'

# This is the complete list of lines from the file
# where each line represents a student
with open(INPUT_FILE_NAME) as file_obj:
  student_scores = file_obj.readlines()

# these are debugging
# print('student_scores:', student_scores)
# print('type of student_scores:', type(student_scores))
# print("Number of lines: ", len(student_scores))
# print("Number of students: ", len(student_scores)-3)


# we have to process each line to create the student dictionary
column_headers = student_scores[0].split(',')
print('column_headers:', column_headers)

due_dates = student_scores[1].split(',')
print('due_dates:', due_dates)

max_points = student_scores[2].split(',')
print('max_points:', max_points)

# slice the list so that we only have student scores.
student_scores = student_scores[3:]


print('student_scores:', student_scores)
print('type of column_headers:', type(column_headers))
students_list = []

for each_line in student_scores:
  # create empty student dictionary
  print('Student Data:', each_line)
  student_data_list = each_line.split(',')
  print('Student Data List:', student_data_list)
  print("=====")

  # populate the dictionary
  # todo

  # add the ditionary to the list
  # todo
# Out:
# column_headers: ['Last Name', 'First Name', 'Email Address', 'Lab 22 (More About Strings)', 'Quiz 18 (slicing and unpacking)', 'Lab 1', 'Quiz 1 (Syllabus)', 'Lab 2 (Variables and Data Types)', 'Quiz 2 (Variables and Data Types)', 'Lab 3', '"Quiz 3 (print', ' input and arithmetic operators)"', 'Lab 4', 'Quiz 4', 'Assignment 1 (Chapter 2 problems 13 and 14)', 'Lab 5 (Exploring Conditions and Boolean Logic)', 'Quiz 5 (Boolean Logic and Conditions)', 'Lab 6 (Conditions - CodingBat problem)', '"Quiz 6 (conditions on conditionals', ' nested conditions)"', 'Assignment 2 (Roulette Wheel Colors)', 'Lab 7 (while loops)', 'Quiz 7 (Iterations #1)', 'Lab 8 ', 'Quiz 8 (for loops and range)', 'Lab 9 (interactive play)', '"Quiz 9 (Chapter 2', ' 3 and 4 Recaps)"', 'Assignment 3 (for and while loops)', 'Lab 10 (Functions - An Introduction)', 'Quiz 10 (Functions - Intro)', '"Quiz 11 (Positional', ' Keyword', ' Optional Arguments)"', 'Assignment 4 (Functions) (Auto-Tester)', '"Lab 11: Functions - Positi
# ...

# %%
#@title Step 1: Declare the file names
INPUT_SCORES_FILE_NAME = "python_101_scores_small.csv"
INPUT_EMAILS_FILE_NAME = "python_101_emails.csv"

# %%
#@title Implement all the helper functions

# %%
#@title Step 2: Parse the scores CSV
# How do we maintain the scores?

"""
This method takes the filename of scores as the input.
And processes the data and returns a list of student dictionaries.
Each student dictionary has the following keys:
first_name: str
last_name: str
email: str
scores: another dictionary {assignment_name: score}

"""

def parse_scores(filename):



# Testing the parse_scores method

# %%
#@title Step 3: Parse the emails CSV
def parse_emails(filename):
  pass

#Testign the parse_emails method
