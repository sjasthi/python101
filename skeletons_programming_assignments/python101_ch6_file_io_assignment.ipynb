# %% [markdown]
# # 📁 File I/O Assignment: Personal Web Page Generator
# ## Python 101 - Chapter 6 (Programming Exercise 11)
#
# **Total Points: 25**
#
# ---
#
# ### Assignment Overview:
# You will create a program that generates a personalized HTML web page based on user input. The program will:
# 1. Ask the user for their name
# 2. Ask the user for a sentence describing themselves
# 3. Create an HTML file with the user's information
# 4. Include proper exception handling for file operations
#
# ### Learning Objectives:
# - Practice file I/O operations (writing to files)
# - Work with string formatting and HTML content
# - Implement exception handling for file operations
# - Create a practical, real-world application
#
# ### What You'll Submit:
# - This completed Jupyter notebook
# - The generated HTML file (webpage.html)
#
# **Good luck! 🚀**

# %% [markdown]
# ---
# ## Part 1: Get User Input (3 points)
#
# **Task:** Write code to get the user's name and description.
#
# **Requirements:**
# - Ask for the user's name
# - Ask for a description sentence
# - Store both in variables
#
# **Hints:**
# - Use the `input()` function
# - Make your prompts clear and friendly
# - Use descriptive variable names

# %%
# Part 1: Get User Input

print("Personal Web Page Generator")
print("=" * 30)

# YOUR CODE HERE: Get user's name
user_name = 

# YOUR CODE HERE: Get user's description
user_description = 

# Display what was entered (for verification)
print("\nThank you! Generating your web page...")

# %% [markdown]
# ---
# ## Part 2: Create HTML Content (5 points)
#
# **Task:** Build the HTML content as a string using the user's input.
#
# **Requirements:**
# - Create a variable that contains the complete HTML structure
# - Use the user's name in the `<h1>` heading
# - Use the user's description in the body
# - Include all necessary HTML tags
#
# **Hints:**
# - You can use triple quotes `"""` for multi-line strings
# - Use f-strings to insert variables: `f"<h1>{variable_name}</h1>"`
# - Make sure to include: `<html>`, `<head>`, `<body>`, `<center>`, `<h1>`, and `<hr />`

# %%
# Part 2: Create HTML Content

# YOUR CODE HERE: Build the HTML content
html_content = f"""











"""

# Display the HTML content (for verification)
print("HTML Content:")
print(html_content)

# %% [markdown]
# ---
# ## Part 3: Write to File (7 points)
#
# **Task:** Write the HTML content to a file named `webpage.html`.
#
# **Requirements:**
# - Open a file named `webpage.html` in write mode
# - Write the HTML content to the file
# - Close the file properly
# - Print a success message
#
# **Hints:**
# - Use `open(filename, 'w')` to open a file in write mode
# - Use the `write()` method to write content
# - Use `close()` to close the file
# - OR use the `with` statement for automatic closing (recommended!)

# %%
# Part 3: Write to File

# YOUR CODE HERE: Open file and write HTML content





print("✅ Web page created successfully!")
print("📄 File saved as: webpage.html")

# %% [markdown]
# ---
# ## Part 4: Add Exception Handling (5 points)
#
# **Task:** Improve your code by adding exception handling to catch potential file I/O errors.
#
# **Requirements:**
# - Wrap your file writing code in a try-except block
# - Catch potential `IOError` or `OSError` exceptions
# - Print an appropriate error message if something goes wrong
# - Print a success message if everything works correctly
#
# **Hints:**
# - Use `try:` before the file operations
# - Use `except IOError as e:` to catch file errors
# - You can use `except Exception as e:` to catch any error

# %%
# Part 4: Write to File with Exception Handling

# YOUR CODE HERE: Add try-except around file operations
try:
    # Open file and write HTML content
    
    
    
    
    print("✅ Web page created successfully!")
    print("📄 File saved as: webpage.html")
    
except IOError as e:
    # YOUR CODE HERE: Handle file I/O errors
    
    
except Exception as e:
    # YOUR CODE HERE: Handle any other errors

# %% [markdown]
# ---
# ## Part 5: Complete Program - Putting It All Together (5 points)
#
# **Task:** Write the complete program in one cell with all parts integrated.
#
# **Requirements:**
# - Get user input (name and description)
# - Create HTML content
# - Write to file with exception handling
# - Include comments explaining each section
#
# **Bonus Features (optional, but recommended):**
# - Validate that user doesn't enter empty strings
# - Add more HTML formatting (like different colors or styles)
# - Allow user to specify the filename

# %%
# Complete Personal Web Page Generator Program

# YOUR COMPLETE CODE HERE
def create_personal_webpage():
    """
    Creates a personal HTML web page based on user input.
    """
    
    # Section 1: Display welcome message
    
    
    # Section 2: Get user input
    
    
    # Section 3: Build HTML content
    
    
    # Section 4: Write to file with exception handling
    
    
    
# Run the program
create_personal_webpage()

# %% [markdown]
# ---
# ## Part 6: Testing and Verification
#
# **Task:** Verify that your HTML file was created correctly.
#
# Run the code below to read and display the contents of your generated HTML file.

# %%
# Verification: Read and display the created HTML file

try:
    with open('webpage.html', 'r') as file:
        content = file.read()
        print("📄 Contents of webpage.html:")
        print("=" * 50)
        print(content)
        print("=" * 50)
except FileNotFoundError:
    print("❌ File 'webpage.html' not found. Make sure you ran Part 3 or 4 first!")
except Exception as e:
    print(f"❌ Error reading file: {e}")

# %% [markdown]
# ---
# ## 🎉 Assignment Complete!
#
# ### Grading Rubric:
#
# | Part | Task | Points |
# |------|------|--------|
# | 1 | Get User Input | 3 |
# | 2 | Create HTML Content | 5 |
# | 3 | Write to File | 7 |
# | 4 | Add Exception Handling | 5 |
# | 5 | Complete Program | 5 |
# | **Total** | **Assignment** | **25** |
#
# ### Submission Checklist:
# - [ ] All code cells run without errors
# - [ ] `webpage.html` file is created successfully
# - [ ] HTML content includes user's name and description
# - [ ] Exception handling is implemented
# - [ ] Comments explain what the code does
# - [ ] Part 5 integrates all components into a complete function
#
# ### How to Submit:
# 1. Make sure you've run all cells and tested your code
# 2. Save this notebook
# 3. Submit both files to Google Classroom:
#    - This Jupyter notebook (.ipynb file)
#    - The generated webpage.html file
#
# **Great job! 🌟**
